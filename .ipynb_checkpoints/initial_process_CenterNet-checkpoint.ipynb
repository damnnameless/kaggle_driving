# %%
# References:
# * Took 3D visualization code from https://www.kaggle.com/zstusnoopy/visualize-the-location-and-3d-bounding-box-of-car
# * CenterNet paper https://arxiv.org/pdf/1904.07850.pdf
# * CenterNet repository https://github.com/xingyizhou/CenterNet

# %%
import numpy as np 
import pandas as pd
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sb
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from math import sin, cos
from scipy.optimize import minimize
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from efficientnet_pytorch import EfficientNet

# %%
img_weight = 2048 - 512
img_height = img_weight // 16 * 5
scaled = 8

def rotate(x, angle):
    x = x + angle
    x = x - (x + np.pi) // (2 * np.pi) * 2 * np.pi
    return x

def im_read(path, fast_mode = False):
    img = cv2.imread(path)
    if not fast_mode and img is not None and len(img.shape) == 3:
        img = np.array(img[:, :, ::-1])
    return img



def str2cor(s, names=['id', 'yaw', 'pitch', 'roll', 'x', 'y', 'z']):
    coords = []
    for l in np.array(s.split(' ')).reshape([-1, 7]):
        coords.append(dict(zip(names, l.astype('float32'))))
        if 'id' in coords[-1]:
            coords[-1]['id'] = int(coords[-1]['id'])
    return coords



def get_img_coords(s):
    coords = str2cor(s)
    x = [i['x'] for i in coords]
    y = [i['y'] for i in coords]
    z = [i['z'] for i in coords]
    P = np.array(list(zip(x, y, z))).T
    img_p = np.dot(camera_matrix, P).T
    img_p[:, 0] /= img_p[:, 2]
    img_p[:, 1] /= img_p[:, 2]
    img_xs = img_p[:, 0]
    img_ys = img_p[:, 1]
    img_zs = img_p[:, 2]
    return img_xs, img_ys



def regr_preprocess(regr_dict, flip=False):
    if flip:
        for k in ['x', 'pitch', 'roll']:
            regr_dict[k] = -regr_dict[k]
    for name in ['x', 'y', 'z']:
        regr_dict[name] = regr_dict[name] / 100
    regr_dict['roll'] = rotate(regr_dict['roll'], np.pi)
    regr_dict['pitch_sin'] = sin(regr_dict['pitch'])
    regr_dict['pitch_cos'] = cos(regr_dict['pitch'])
    regr_dict.pop('pitch')
    regr_dict.pop('id')
    return regr_dict



def regr_back(regr_dict):
    for name in ['x', 'y', 'z']:
        regr_dict[name] = regr_dict[name] * 100
    regr_dict['roll'] = rotate(regr_dict['roll'], -np.pi)
    pitch_sin = regr_dict['pitch_sin'] / np.sqrt(regr_dict['pitch_sin']**2 + regr_dict['pitch_cos']**2)
    pitch_cos = regr_dict['pitch_cos'] / np.sqrt(regr_dict['pitch_sin']**2 + regr_dict['pitch_cos']**2)
    regr_dict['pitch'] = np.arccos(pitch_cos) * np.sign(pitch_sin)
    return regr_dict



def preprocess_image(img, flip=False):
    img = img[img.shape[0] // 2:]
    bg = np.ones_like(img) * img.mean(1, keepdims=True).astype(img.dtype)
    bg = bg[:, :img.shape[1] // 6]
    img = np.concatenate([bg, img, bg], 1)
    img = cv2.resize(img, (img_weight, img_height))
    if flip:
        img = img[:,::-1]
    return (img / 255).astype('float32')



def get_mask_and_regr(img, labels, flip=False):
    mask = np.zeros([img_height // scaled, img_weight // scaled], dtype='float32')
    regr_names = ['x', 'y', 'z', 'yaw', 'pitch', 'roll']
    regr = np.zeros([img_height // scaled, img_weight // scaled, 7], dtype='float32')
    coords = str2cor(labels)
    xs, ys = get_img_coords(labels)
    for x, y, regr_dict in zip(xs, ys, coords):
        x, y = y, x
        x = (x - img.shape[0] // 2) * img_height / (img.shape[0] // 2) / scaled
        x = np.round(x).astype('int')
        y = (y + img.shape[1] // 6) * img_weight / (img.shape[1] * 4/3) / scaled
        y = np.round(y).astype('int')
        if x >= 0 and x < img_height // scaled and y >= 0 and y < img_weight // scaled:
            mask[x, y] = 1
            regr_dict = regr_preprocess(regr_dict, flip)
            regr[x, y] = [regr_dict[n] for n in sorted(regr_dict)]
    if flip:
        mask = np.array(mask[:,::-1])
        regr = np.array(regr[:,::-1])
    return mask, regr

# %%
path_dir = '../Resources/'
df_train = pd.read_csv('../Resources/train.csv')
camera_matrix = np.array([[2304.5479, 0,  1686.2379],
                          [0, 2305.8757, 1354.9849],
                          [0, 0, 1]], dtype=np.float32)
camera_matrix_inv = np.linalg.inv(camera_matrix)
img = im_read(path_dir + 'train_images/ID_8a6e65317' + '.jpg')
img_shape = img.shape

# %%
# show the image and mask and mask after regr(add how far away from the camera)
img_init = im_read(path_dir + 'train_images/' + df_train['ImageId'][2217] + '.jpg')
img_pre = preprocess_image(img_init)

mask_init, regr_init = get_mask_and_regr(img_init, df_train['PredictionString'][2217])
plt.figure(figsize=(16,16))
plt.title('Processed image')
plt.imshow(img_pre)
plt.show()

plt.figure(figsize=(16,16))
plt.title('Detection Mask')
plt.imshow(mask_init)
plt.show()

plt.figure(figsize=(16,16))
plt.title('Yaw values')
plt.imshow(regr_init[:,:,-2])
plt.show()

# %%
# pytorch dataset for separate and story train dataset and test dataset in pytorch dataset
class car_data(Dataset):


    def __init__(self, data_frame, root_dir, transform=None):
        self.df = data_frame
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    # __getitem__ to show the image
    def __getitem__(self, i):
        # test whether i is a array
        if torch.is_tensor(i):
            i = i.tolist()
        
        # Get image name
        # i = first columns of pandas which is the id
        # labels is the mask position str
        i, label = self.df.to_numpy()[i]
        # get the image name
        img_name = self.root_dir.format(i)
        
        # Read image
        img_init = im_read(img_name, True)
        img = preprocess_image(img_init, flip= False)
        img = np.rollaxis(img, 2, 0)
        
        # Get mask and regression maps
        mask, regr = get_mask_and_regr(img_init, label, flip=False)
        regr = np.rollaxis(regr, 2, 0)
        
        return [img, mask, regr]

# %%
train_image_dir = path_dir + 'train_images/{}.jpg'
test_image_dir = path_dir + 'test_images/{}.jpg'
df_init_train, df_init_test = train_test_split(df_train, test_size=0.01, random_state=42)
df_real_test = pd.read_csv('../Resources/sample_submission.csv')
train_dataset = car_data(df_init_train, train_image_dir)
test_dataset = car_data(df_init_test, train_image_dir)
test_real_dataset = car_data(df_real_test, test_image_dir)

# %%
img, mask, regr = train_dataset[2217]

plt.figure(figsize=(16,16))
plt.imshow(np.rollaxis(img, 0, 3))
plt.show()

plt.figure(figsize=(16,16))
plt.imshow(mask)
plt.show()

plt.figure(figsize=(16,16))
plt.imshow(regr[-2])
plt.show()

# %%
batch_size = 2

# Create data generators by dataloader
train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True, num_workers = 4)
test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False, num_workers = 4)
test_real_loader = DataLoader(dataset = test_real_dataset, batch_size = batch_size, shuffle = False, num_workers = 4)

# %%
# double speed up by conv2d, bn, relu, conv2d, bn, relu
class double_conv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x
    


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()
        # try to use covtranspose if it can be run
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2=None):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        
        
        if x2 is not None:
            x = torch.cat([x2, x1], dim=1)
        else:
            x = x1
        x = self.conv(x)
        return x
def get_mesh(batch_size, shape_x, shape_y):
    # making grid
    img_x, img_y = np.meshgrid(np.linspace(0, 1, shape_y), np.linspace(0, 1, shape_x))
    # repeating mg_x and mg_y for batch size
    img_x = np.tile(img_x[None, None, :, :], [batch_size, 1, 1, 1]).astype('float32')
    img_y = np.tile(img_y[None, None, :, :], [batch_size, 1, 1, 1]).astype('float32')
    # Concatenates the given sequence of seq tensors
    mesh = torch.cat([torch.tensor(img_x).to(device), torch.tensor(img_y).to(device)], 1)
    return mesh

# %%
class my_net(nn.Module):
    def __init__(self, n_classes):
        super(my_net, self).__init__()
        self.base_model = EfficientNet.from_pretrained('efficientnet-b0')
        self.conv0 = double_conv(5, 64)
        self.conv1 = double_conv(64, 128)
        self.conv2 = double_conv(128, 512)
        self.conv3 = double_conv(512, 1024)
        # 2D max pooling 
        self.mp = nn.MaxPool2d(2)
        # upsampling
        self.up1 = up(1282 + 1024, 512)
        self.up2 = up(512 + 512, 256)
        self.outc = nn.Conv2d(256, n_classes, 1)

    def forward(self, x):
        batch_size = x.shape[0]
        mesh1 = get_mesh(batch_size, x.shape[2], x.shape[3])
        x0 = torch.cat([x, mesh1], 1)
        x1 = self.mp(self.conv0(x0))
        x2 = self.mp(self.conv1(x1))
        x3 = self.mp(self.conv2(x2))
        x4 = self.mp(self.conv3(x3))
        
        x_center = x[:, :, :, IMG_WIDTH // 8: -IMG_WIDTH // 8]
        feats = self.base_model.extract_features(x_center)
        bg = torch.zeros([feats.shape[0], feats.shape[1], feats.shape[2], feats.shape[3] // 8]).to(device)
        feats = torch.cat([bg, feats, bg], 3)
        
        # Add positional info
        mesh2 = get_mesh(batch_size, feats.shape[2], feats.shape[3])
        feats = torch.cat([feats, mesh2], 1)
        
        x = self.up1(feats, x4)
        x = self.up2(x, x3)
        x = self.outc(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_epoch = 10
model_init = my_net(8).to(device)
optimizer = torch.optim.Adam(model_init.parameters(), lr=0.001)
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=max(n_epoch, 10) * len(train_loader) // 3, gamma=0.1)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
# Binary mask loss
def criterion(prediction, mask, regr, size_average=True):
    pred_mask = torch.sigmoid(prediction[:, 0])
    mask_loss = mask * torch.log(pred_mask + 1e-12) + (1 - mask) * torch.log(1 - pred_mask + 1e-12)
    mask_loss = -mask_loss.mean(0).sum()
    
    # Regression L1 loss
    pred_regr = prediction[:, 1:]
    regr_loss = (torch.abs(pred_regr - regr).sum(1) * mask).sum(1).sum(1) / mask.sum(1).sum(1)
    regr_loss = regr_loss.mean(0)
    
    # Sum
    loss = mask_loss + regr_loss
    if not size_average:
        loss *= prediction.shape[0]
    return loss

# %%
def train_model(epoch, history=None):
    model_init.train()

    for batch_idx, (img_batch, mask_batch, regr_batch) in enumerate(tqdm(train_loader)):
        img_batch = img_batch.to(device)
        mask_batch = mask_batch.to(device)
        regr_batch = regr_batch.to(device)
        
        optimizer.zero_grad()
        output = model_init(img_batch)
        # calculate loss and story them
        loss = criterion(output, mask_batch, regr_batch)
        if history is not None:
            history.loc[epoch + batch_idx / len(train_loader), 'train_loss'] = loss.data.cpu().numpy()
        
        loss.backward()
        
        optimizer.step()
        exp_lr_scheduler.step()
    
    print('Train Epoch: {} \nLR: {:.6f}\nLoss: {:.6f}'.format(
        epoch,
        optimizer.state_dict()['param_groups'][0]['lr'],
        loss.data))
    print('*'* 25)

# test the model for testing
def test_model(epoch, history=None):
    model_init.eval()
    loss = 0
    
    with torch.no_grad():
        for img_batch, mask_batch, regr_batch in test_loader:
            img_batch = img_batch.to(device)
            mask_batch = mask_batch.to(device)
            regr_batch = regr_batch.to(device)

            output = model(img_batch)

            loss += criterion(output, mask_batch, regr_batch, size_average=False).data
    
    loss /= len(test_loader.dataset)
    
    if history is not None:
        history.loc[epoch, 'dev_loss'] = loss.cpu().numpy()
    
    print('Dev loss: {:.4f}'.format(loss))

# %%
# %%time

history = pd.DataFrame()

for epoch in range(n_epoch):
    train_model(epoch, history)
    evaluate_model(epoch, history)
# Out:
#   0%|          | 0/2110 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#
# ...
